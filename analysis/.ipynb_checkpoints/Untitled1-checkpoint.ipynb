# %%
import pandas as pd 
import json
import matplotlib.pyplot as plt

# %%
path_to_iota_data = "../node-app/iota_data.csv"
path_to_node_data = "../node-app/node_data.csv"

df_iota = pd.read_csv(path_to_iota_data)
df_node = pd.read_csv(path_to_node_data)

# %%
df_iota['total_RTT'] = df_iota['timeToSync'] + df_iota['timeToReceiveMessage']
df_iota
# Out:
#           datetime                   auth_node                    sub_node  \
# 0    1648232809052  http://54.177.214.21:14265  http://54.177.214.21:14265
# 1    1648232815537  http://54.177.214.21:14265  http://54.177.214.21:14265
# 2    1648232818560  http://54.177.214.21:14265  http://54.177.214.21:14265
# 3    1648232819169  http://54.177.214.21:14265  http://54.177.214.21:14265
# 4    1648232825017  http://54.177.214.21:14265  http://54.177.214.21:14265
# ..             ...                         ...                         ...
# 787  1649894425972  http://54.177.214.21:14265  http://54.177.214.21:14265
# 788  1649894451769  http://54.177.214.21:14265  http://54.177.214.21:14265
# 789  1649894468264  http://54.177.214.21:14265  http://54.177.214.21:14265
# 790  1649894479221  http://54.177.214.21:14265  http://54.177.214.21:14265
# 791  1649894482797  http://54.177.214.21:14265  http://54.177.214.21:14265
#
#      same_auth_sub  local_pow  timeToSync  timeToReceiveMessage  \
# 0             True      False         280                  1346
# 1             True      False         103                  6326
# 2             True      False         121                  2843
# 3             True      False         114                   442
# 4             True      False         122                  5667
# ..             ...        ...         ...                   ...
# 787           True      False         334                 40169
# 788           True      False         347                 25285
# 789           True      False         331                 15996
# 790           True      False         335                 10457
# 791           True      False         330                  3083
#
#      packet_size_bytes  total_RTT
# 0                    2       1626
# 1                    2       6429
# 2                    2       2964
# 3                    2        556
# 4                    2       5789
# ..                 ...        ...
# 787               1024      40503
# 788               1024      25632
# 789               1024      16327
# 790               1024      10792
# 791               1024       3413
#
# [792 rows x 9 columns]

# %%
import seaborn as sns
# who v/s fare barplot
 
sns.barplot(x = 'same_auth_sub',
            y = 'timeToSync',
            data = df_iota)
 
# Show the plot
plt.show()

# %%
df_iota_very_small = df_iota[df_iota['packet_size_bytes'] < 100] 
df_iota_small = df_iota[df_iota['packet_size_bytes'] < 600] 
df_iota_small
# Out:
#           datetime                   auth_node                    sub_node  \
# 0    1648232809052  http://54.177.214.21:14265  http://54.177.214.21:14265
# 1    1648232815537  http://54.177.214.21:14265  http://54.177.214.21:14265
# 2    1648232818560  http://54.177.214.21:14265  http://54.177.214.21:14265
# 3    1648232819169  http://54.177.214.21:14265  http://54.177.214.21:14265
# 4    1648232825017  http://54.177.214.21:14265  http://54.177.214.21:14265
# ..             ...                         ...                         ...
# 778  1649894190821  http://54.177.214.21:14265  http://54.177.214.21:14265
# 779  1649894205262  http://54.177.214.21:14265  http://54.177.214.21:14265
# 780  1649894212445  http://54.177.214.21:14265  http://54.177.214.21:14265
# 781  1649894229250  http://54.177.214.21:14265  http://54.177.214.21:14265
# 782  1649894247203  http://54.177.214.21:14265  http://54.177.214.21:14265
#
#      same_auth_sub  local_pow  timeToSync  timeToReceiveMessage  \
# 0             True      False         280                  1346
# 1             True      False         103                  6326
# 2             True      False         121                  2843
# 3             True      False         114                   442
# 4             True      False         122                  5667
# ..             ...        ...         ...                   ...
# 778           True      False         334                 10624
# 779           True      False         330                 13947
# 780           True      False         329                  6690
# 781           True      False         334                 16306
# 782           True      False         338                 17453
#
#      packet_size_bytes  total_RTT
# 0                    2       1626
# 1                    2       6429
# 2                    2       2964
# 3                    2        556
# 4                    2       5789
# ..                 ...        ...
# 778                512      10958
# 779                512      14277
# 780                512       7019
# 781                512      16640
# 782                512      17791
#
# [774 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(16,12))
# who v/s fare barplot



ax_1 = sns.pointplot(x = 'packet_size_bytes',
            y = 'timeToReceiveMessage',
            data = df_iota_small,
                    color = 'blue')

ax_2 = sns.pointplot(x = 'packet_size_bytes',
            y = 'timeToSync',
            data = df_iota_small,
           color = 'red')

ax_2 = sns.pointplot(x = 'packet_size_bytes',
            y = 'total_RTT',
            data = df_iota_small,
           color = 'green')

ax_2.set_ylabel("Time")

import matplotlib.patches as mpatches

red_patch = mpatches.Patch(color='blue', label='timeToReceiveMessage')
black_patch = mpatches.Patch(color='red', label='timeToSyncNetwork')
plt.legend(handles=[red_patch, black_patch])
plt.ylabel.upper()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,12))

ax1 = sns.pointplot(x = 'packet_size_bytes',
            y = 'timeToReceiveMessage',
            data = df_node)

# %%
df_node
# Out:
#           datetime  timeToReceiveMessage  packet_size_bytes
# 0    1648231818144                   108               2000
# 1    1648231818209                    86               2000
# 2    1648231818274                    86               2000
# 3    1648231818331                    79               2000
# 4    1648231818396                    86               2000
# ..             ...                   ...                ...
# 338  1649893623398                   128               1000
# 339  1649893624576                   136               1000
# 340  1649893625747                   129               1000
# 341  1649893626917                   130               1000
# 342  1649893628096                   134               1000
#
# [343 rows x 3 columns]

# %%
fig, ax = plt.subplots()

ax = sns.lineplot(x = 'packet_size_bytes',
            y = 'timeToReceiveMessage',
            data = df_iota)

ax1 = sns.lineplot(x = 'packet_size_bytes',
            y = 'timeToReceiveMessage',
            data = df_node)

# %%
df_node_grouped = df_node.groupby("packet_size_bytes").mean()

# %%
df_iota_grouped = df_iota.groupby("packet_size_bytes").mean()
df_iota_grouped = df_iota_grouped.drop(columns=['same_auth_sub', 'local_pow', 'datetime'])
df_iota_grouped
# Out:
#                    timeToSync  timeToReceiveMessage
# packet_size_bytes
# 2                  908.700000           4280.700000
# 4                  787.592593           5037.814815
# 2000               162.250000          11961.250000

# %%
path_to_network_data = "../node-app/iota_network_data.csv"
df_network = pd.read_csv(path_to_network_data)

# %%
df_network
# Out:
#             time    node                   url         network_id  \
# 0     1648451400  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1     1648452000  HORNET  http://54.177.214.21  chrysalis-mainnet
# 2     1648452600  HORNET  http://54.177.214.21  chrysalis-mainnet
# 3     1648453200  HORNET  http://54.177.214.21  chrysalis-mainnet
# 4     1648453800  HORNET  http://54.177.214.21  chrysalis-mainnet
# ...          ...     ...                   ...                ...
# 1992  1649647200  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1993  1649647800  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1994  1649648400  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1995  1649649000  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1996  1649649600  HORNET  http://54.177.214.21  chrysalis-mainnet
#
#       messages_per_second  is_healthy
# 0                    16.1        True
# 1                    16.1        True
# 2                    13.7        True
# 3                    19.5        True
# 4                     9.2        True
# ...                   ...         ...
# 1992                 11.7        True
# 1993                 12.2        True
# 1994                 13.1        True
# 1995                 11.9        True
# 1996                 16.4        True
#
# [1997 rows x 6 columns]

# %%
import seaborn as sns

fig, ax = plt.subplots()

ax = sns.lineplot(x = 'time',
            y = 'is_healthy',
            data = df_network)

# ax1 = sns.lineplot(x = 'packet_size_bytes',
#             y = 'timeToReceiveMessage',
#             data = df_node)

# %%
import datetime

date_trans = []
for index, row in df_network.iterrows():
    date_trans.append(datetime.datetime.utcfromtimestamp(int(df_network['time'][index])))
    
print(date_trans)
df_network['date_trans'] = date_trans
df_network
# Out:
# [datetime.datetime(2022, 3, 28, 7, 10), datetime.datetime(2022, 3, 28, 7, 20), datetime.datetime(2022, 3, 28, 7, 30), datetime.datetime(2022, 3, 28, 7, 40), datetime.datetime(2022, 3, 28, 7, 50), datetime.datetime(2022, 3, 28, 8, 0), datetime.datetime(2022, 3, 28, 8, 10), datetime.datetime(2022, 3, 28, 8, 20), datetime.datetime(2022, 3, 28, 8, 30), datetime.datetime(2022, 3, 28, 8, 40), datetime.datetime(2022, 3, 28, 8, 50), datetime.datetime(2022, 3, 28, 9, 0), datetime.datetime(2022, 3, 28, 9, 10), datetime.datetime(2022, 3, 28, 9, 20), datetime.datetime(2022, 3, 28, 9, 30), datetime.datetime(2022, 3, 28, 9, 40), datetime.datetime(2022, 3, 28, 9, 50), datetime.datetime(2022, 3, 28, 10, 0), datetime.datetime(2022, 3, 28, 10, 10), datetime.datetime(2022, 3, 28, 10, 20), datetime.datetime(2022, 3, 28, 10, 30), datetime.datetime(2022, 3, 28, 10, 40), datetime.datetime(2022, 3, 28, 10, 50), datetime.datetime(2022, 3, 28, 11, 0), datetime.datetime(2022, 3, 28, 11, 10), datetime.datetime(2022, 3, 28, 11, 20), datetime.datetime(2022, 3, 28, 11, 30), datetime.datetime(2022, 3, 28, 11, 40), datetime.datetime(2022, 3, 28, 11, 50), datetime.datetime(2022, 3, 28, 12, 0), datetime.datetime(2022, 3, 28, 12, 10), datetime.datetime(2022, 3, 28, 12, 20), datetime.datetime(2022, 3, 28, 12, 30), datetime.datetime(2022, 3, 28, 12, 40), datetime.datetime(2022, 3, 28, 12, 50), datetime.datetime(2022, 3, 28, 13, 0), datetime.datetime(2022, 3, 28, 13, 10), datetime.datetime(2022, 3, 28, 13, 20), datetime.datetime(2022, 3, 28, 13, 30), datetime.datetime(2022, 3, 28, 13, 40), datetime.datetime(2022, 3, 28, 13, 50), datetime.datetime(2022, 3, 28, 14, 0), datetime.datetime(2022, 3, 28, 14, 10), datetime.datetime(2022, 3, 28, 14, 20), datetime.datetime(2022, 3, 28, 14, 30), datetime.datetime(2022, 3, 28, 14, 40), datetime.datetime(2022, 3, 28, 14, 50), datetime.datetime(2022, 3, 28, 15, 0), datetime.datetime(2022, 3, 28, 15, 10), datetime.datetime(2022, 3, 28, 15, 20), datetime.datetime(2022, 3, 28, 15, 30), datetime.datetime(2022, 3, 28, 15, 40), datetime.datetime(2022, 3, 28, 15, 50), datetime.datetime(2022, 3, 28, 16, 0), datetime.datetime(2022, 3, 28, 16, 10), datetime.datetime(2022, 3, 28, 16, 20), datetime.datetime(2022, 3, 28, 16, 30), datetime.datetime(2022, 3, 28, 16, 40), datetime.datetime(2022, 3, 28, 16, 50), datetime.datetime(2022, 3, 28, 17, 0), datetime.datetime(2022, 3, 28, 17, 10), datetime.datetime(2022, 3, 28, 17, 20), datetime.datetime(2022, 3, 28, 17, 30), datetime.datetime(2022, 3, 28, 17, 40), datetime.datetime(2022, 3, 28, 17, 50), datetime.datetime(2022, 3, 28, 18, 0), datetime.datetime(2022, 3, 28, 18, 10), datetime.datetime(2022, 3, 28, 18, 20), datetime.datetime(2022, 3, 28, 18, 30), datetime.datetime(2022, 3, 28, 18, 40), datetime.datetime(2022, 3, 28, 18, 50), datetime.datetime(2022, 3, 28, 19, 0), datetime.datetime(2022, 3, 28, 19, 10), datetime.datetime(2022, 3, 28, 19, 20), datetime.datetime(2022, 3, 28, 19, 30), datetime.datetime(2022, 3, 28, 19, 40), datetime.datetime(2022, 3, 28, 19, 50), datetime.datetime(2022, 3, 28, 20, 0), datetime.datetime(2022, 3, 28, 20, 10), datetime.datetime(2022, 3, 28, 20, 20), datetime.datetime(2022, 3, 28, 20, 30), datetime.datetime(2022, 3, 28, 20, 40), datetime.datetime(2022, 3, 28, 20, 50), datetime.datetime(2022, 3, 28, 21, 0), datetime.datetime(2022, 3, 28, 21, 10), datetime.datetime(2022, 3, 28, 21, 20), datetime.datetime(2022, 3, 28, 21, 30), datetime.datetime(2022, 3, 28, 21, 40), datetime.datetime(2022, 3, 28, 21, 50), datetime.datetime(2022, 3, 28, 22, 0), datetime.datetime(2022, 3, 28, 22, 10), datetime.datetime(2022, 3, 28, 22, 20), datetime.datetime(2022, 3, 28, 22, 30), datetime.datetime(2022, 3, 28, 22, 40), datetime.datetime(2022, 3, 28, 22, 50), datetime.datetime(2022, 3, 28, 23, 0), datetime.datetime(2022, 3, 28, 23, 10), datetime.datetime(2022, 3, 28, 23, 20), datetime.datetime(2022, 3, 28, 23, 30), datetime.datetime(2022, 3, 28, 23, 40), datetime.datetime(2022, 3, 28, 2 ...
#             time    node                   url         network_id  \
# 0     1648451400  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1     1648452000  HORNET  http://54.177.214.21  chrysalis-mainnet
# 2     1648452600  HORNET  http://54.177.214.21  chrysalis-mainnet
# 3     1648453200  HORNET  http://54.177.214.21  chrysalis-mainnet
# 4     1648453800  HORNET  http://54.177.214.21  chrysalis-mainnet
# ...          ...     ...                   ...                ...
# 1993  1649647200  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1994  1649647800  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1995  1649648400  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1996  1649649000  HORNET  http://54.177.214.21  chrysalis-mainnet
# 1997  1649649600  HORNET  http://54.177.214.21  chrysalis-mainnet
#
#       messages_per_second  is_healthy          date_trans
# 0                    16.1        True 2022-03-28 07:10:00
# 1                    16.1        True 2022-03-28 07:20:00
# 2                    13.7        True 2022-03-28 07:30:00
# 3                    19.5        True 2022-03-28 07:40:00
# 4                     9.2        True 2022-03-28 07:50:00
# ...                   ...         ...                 ...
# 1993                 12.2        True 2022-04-11 03:20:00
# 1994                 12.2        True 2022-04-11 03:30:00
# 1995                 13.1        True 2022-04-11 03:40:00
# 1996                 11.9        True 2022-04-11 03:50:00
# 1997                 16.4        True 2022-04-11 04:00:00
#
# [1998 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax = sns.lineplot(x = 'time',
            y = 'is_healthy',
            data = df_network)

# %%
df_network["is_healthy"].count()
# Out:
# 1997

# %%
total = 1997
false = 14 
true = total - false

true_percent = true / total 
false_percent = 1 - true_percent

print(true_percent)
print(false_percent)
# Out:
# 0.9929894842263395
# 0.0070105157736605195

# %%
true
# Out:
# 1983

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(df_network['messages_per_second'])
  
# Calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
  
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/86/d1pz7hms1rjf15kdvq3kf5km0000gn/T/ipykernel_17099/2159072431.py in <module>
#       5
#       6 # Plot between -10 and 10 with .001 steps.
# ----> 7 x_axis = np.arange(df_network['messages_per_second'])
#       8
#       9 # Calculating mean and standard deviation
#
# ~/projects/meng-project-iota-saev/analysis/venv-node/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_network['messages_per_second'].mean()
df_network['messages_per_second'].std()

messages_per_second = []
for index, row in df_network.iterrows():
    messages_per_second.append(df_network['messages_per_second'][index])
    
messages_per_second
# Out:
# [16.1,
#  16.1,
#  13.7,
#  19.5,
#  9.2,
#  14.5,
#  15.3,
#  15.1,
#  14.6,
#  9.8,
#  13.5,
#  13.4,
#  12.3,
#  12.1,
#  15.4,
#  13.2,
#  16.0,
#  13.4,
#  13.6,
#  13.9,
#  15.2,
#  15.5,
#  11.3,
#  13.1,
#  13.4,
#  15.3,
#  9.8,
#  13.6,
#  11.9,
#  11.2,
#  17.9,
#  7.7,
#  15.6,
#  15.6,
#  9.3,
#  9.3,
#  15.0,
#  14.1,
#  14.2,
#  6.9,
#  6.9,
#  14.2,
#  14.6,
#  0.2,
#  13.6,
#  12.6,
#  12.9,
#  20.3,
#  5.9,
#  14.7,
#  15.3,
#  15.1,
#  15.5,
#  13.1,
#  12.9,
#  14.8,
#  11.4,
#  11.4,
#  15.5,
#  13.0,
#  17.2,
#  9.8,
#  9.3,
#  13.5,
#  14.6,
#  14.1,
#  13.3,
#  15.0,
#  15.4,
#  21.1,
#  6.9,
#  13.8,
#  13.2,
#  17.4,
#  13.4,
#  11.4,
#  15.0,
#  15.9,
#  9.0,
#  10.0,
#  17.2,
#  19.7,
#  10.4,
#  14.4,
#  12.1,
#  14.6,
#  11.5,
#  14.8,
#  14.1,
#  14.9,
#  20.2,
#  12.8,
#  11.8,
#  14.1,
#  12.1,
#  12.5,
#  14.8,
#  13.5,
#  12.1,
#  20.5,
#  8.8,
#  12.0,
#  13.9,
#  15.3,
#  12.8,
#  14.2,
#  12.5,
#  22.4,
#  11.2,
#  8.3,
#  14.5,
#  12.8,
#  16.3,
#  13.3,
#  13.6,
#  13.2,
#  16.6,
#  16.9,
#  12.3,
#  13.5,
#  15.1,
#  13.9,
#  11.1,
#  13.2,
#  15.2,
#  14.2,
#  12.6,
#  14.0,
#  14.9,
#  12.7,
#  15.7,
#  11.4,
#  13.5,
#  12.8,
#  12.9,
#  15.6,
#  16.1,
#  17.0,
#  16.0,
#  17.4,
#  9.5,
#  13.5,
#  14.6,
#  12.9,
#  12.1,
#  13.3,
#  13.4,
#  14.7,
#  13.4,
#  13.2,
#  18.2,
#  7.1,
#  14.7,
#  15.1,
#  12.2,
#  12.9,
#  15.3,
#  13.0,
#  19.0,
#  9.8,
#  15.1,
#  17.0,
#  12.4,
#  15.8,
#  12.6,
#  11.1,
#  11.9,
#  14.9,
#  14.0,
#  17.9,
#  10.5,
#  9.2,
#  17.0,
#  13.4,
#  12.0,
#  13.8,
#  12.5,
#  14.5,
#  19.5,
#  8.2,
#  17.1,
#  12.6,
#  13.1,
#  15.0,
#  14.5,
#  15.7,
#  15.8,
#  18.3,
#  14.3,
#  16.3,
#  10.6,
#  15.8,
#  10.6,
#  15.7,
#  13.7,
#  13.7,
#  15.9,
#  13.9,
#  8.9,
#  8.1,
#  16.8,
#  11.9,
#  14.7,
#  13.0,
#  13.9,
#  13.3,
#  20.9,
#  8.3,
#  16.0,
#  8.4,
#  16.4,
#  16.5,
#  11.7,
#  0.0,
#  0.0,
#  0.0,
#  12.1,
#  21.0,
#  8.4,
#  14.8,
#  15.3,
#  12.3,
#  11.2,
#  14.1,
#  12.8,
#  14.0,
#  15.3,
#  19.3,
#  12.7,
#  11.9,
#  14.2,
#  11.5,
#  13.5,
#  14.2,
#  13.0,
#  15.4,
#  15.9,
#  18.9,
#  7.9,
#  16.3,
#  10.5,
#  12.0,
#  17.1,
#  12.0,
#  13.6,
#  14.6,
#  8.8,
#  10.8,
#  16.9,
#  11.0,
#  14.2,
#  12.2,
#  14.5,
#  13.0,
#  15.1,
#  14.6,
#  17.0,
#  7.7,
#  14.0,
#  13.4,
#  11.4,
#  15.6,
#  12.7,
#  12.0,
#  12.0,
#  20.0,
#  10.1,
#  14.0,
#  12.1,
#  16.5,
#  12.1,
#  12.9,
#  13.9,
#  21.4,
#  7.4,
#  11.4,
#  11.1,
#  13.4,
#  15.3,
#  13.8,
#  11.5,
#  12.5,
#  23.9,
#  5.5,
#  13.3,
#  13.3,
#  13.7,
#  14.9,
#  10.3,
#  14.2,
#  0.0,
#  10.2,
#  13.5,
#  12.5,
#  13.0,
#  18.3,
#  11.6,
#  15.0,
#  11.0,
#  19.1,
#  10.8,
#  13.7,
#  12.5,
#  13.9,
#  19.4,
#  8.3,
#  12.5,
#  14.1,
#  9.1,
#  9.0,
#  13.9,
#  15.1,
#  13.8,
#  8.4,
#  13.7,
#  15.7,
#  21.4,
#  9.7,
#  15.3,
#  12.2,
#  14.3,
#  23.4,
#  6.2,
#  14.8,
#  13.5,
#  13.1,
#  15.1,
#  12.9,
#  15.5,
#  12.4,
#  4.0,
#  0.0,
#  15.6,
#  13.0,
#  20.2,
#  10.1,
#  10.4,
#  13.1,
#  13.4,
#  1.9,
#  12.6,
#  12.0,
#  12.0,
#  19.9,
#  7.2,
#  14.9,
#  12.3,
#  12.3,
#  13.6,
#  14.9,
#  14.7,
#  14.8,
#  13.1,
#  13.3,
#  13.8,
#  14.4,
#  14.8,
#  12.3,
#  10.3,
#  13.4,
#  11.4,
#  5.0,
#  11.8,
#  12.6,
#  11.6,
#  17.2,
#  10.3,
#  13.1,
#  13.9,
#  15.6,
#  11.4,
#  15.5,
#  13.6,
#  13.6,
#  8.7,
#  18.4,
#  13.5,
#  16.4,
#  9.6,
#  12.0,
#  12.4,
#  12.7,
#  12.9,
#  14.1,
#  11.2,
#  11.2,
#  17.3,
#  11.4,
#  12.3,
#  12.8,
#  13.1,
#  13.4,
#  14.0,
#  15.6,
#  12.6,
#  19.0,
#  3.1,
#  13.9,
#  12.8,
#  14.8,
#  13.4,
#  14.5,
#  11.5,
#  13.7,
#  21.0,
#  7.5,
#  14.1,
#  14.5,
#  17.7,
#  16.8,
#  15.3,
#  12.9,
#  14.9,
#  21.4,
#  9.8,
#  15.1,
#  16.8,
#  12.1,
#  15.8,
#  15.8,
#  12.3,
#  12.3,
#  7.0,
#  17.7,
#  14.7,
#  17.3,
#  11.0,
#  12.1,
#  14.4,
#  14.3,
#  14.9,
#  16.3,
#  15.0,
#  17.1,
#  13.4,
#  14.8,
#  12.8,
#  15.4,
#  11.6,
#  13.7,
#  13.3,
#  13.9,
#  12.5,
#  18.6,
#  9.0,
#  12.3,
#  15.3,
#  13.7,
#  15.1,
#  14.5,
#  14.2,
#  14.9,
#  19.3,
#  7.7,
#  12.2,
#  14.4,
#  14.9,
#  14.6,
#  13.5,
#  14.1,
#  12.4,
#  15.8,
#  13.5,
#  13.5,
#  14.4,
#  14.0,
#  0.0,
#  11.5,
#  14.8,
#  14.1,
#  11.5,
#  12.0,
#  15.1,
#  12.1,
#  17.2,
#  11.4,
#  16.3,
#  9.7,
#  15.4,
#  15.4,
#  12.4,
#  12.9,
#  17.9,
#  11.1,
#  11.1,
#  16.4,
#  9.7,
#  11.4,
#  12.3,
#  14.7,
#  14.7,
#  17.0,
#  9.0,
#  9.0,
#  6.5,
#  13.9,
#  13.9,
#  12.8,
#  13.7,
#  12.1,
#  12.1,
#  15.8,
#  11.3,
#  12.3,
#  14.0,
#  12.6,
#  13.1,
#  14.1,
#  11.1,
#  14.7,
#  15.6,
#  12.9,
#  12.0,
#  16.1,
#  12.8,
#  15.8,
#  13.0,
#  12.4,
#  15.1,
#  14.5,
#  12.3,
#  19.2,
#  15.2,
#  10.2,
#  15.0,
#  14.3,
#  15.5,
#  12.0,
#  13.0,
#  12.8,
#  20.4,
#  10.0,
#  13.8,
#  14.8,
#  14.0,
#  14.3,
#  13.7,
#  13.6,
#  13.6,
#  20.0,
#  7.3,
#  14.1,
#  14.6,
#  13.0,
#  11.4,
#  11.9,
#  16.9,
#  14.6,
#  13.8,
#  14.2,
#  14.8,
#  12.1,
#  13.9,
#  11.0,
#  13.5,
#  15.7,
#  15.2,
#  16.4,
#  18.1,
#  12.5,
#  8.6,
#  18.0,
#  10.2,
#  14.6,
#  12.7,
#  15.7,
#  15.1,
#  17.7,
#  9.8,
#  18.3,
#  11.2,
#  12.1,
#  12.8,
#  14.1,
#  17.4,
#  18.5,
#  9.5,
#  12.5,
#  21.1,
#  8.6,
#  16.7,
#  14.4,
#  15.2,
#  14.5,
#  19.0,
#  8.4,
#  12.6,
#  8.9,
#  8.5,
#  15.2,
#  11.6,
#  16.3,
#  14.2,
#  13.4,
#  14.1,
#  21.7,
#  8.3,
#  15.3,
#  12.0,
#  13.2,
#  13.8,
#  13.7,
#  13.9,
#  14.6,
#  13.2,
#  13.1,
#  17.1,
#  12.7,
#  15.4,
#  11.8,
#  13.6,
#  15.0,
#  13.4,
#  15.6,
#  15.6,
#  10.4,
#  11.1,
#  14.8,
#  11.1,
#  17.0,
#  14.3,
#  14.2,
#  14.8,
#  19.1,
#  12.9,
#  7.1,
#  12.6,
#  9.9,
#  15.2,
#  13.5,
#  14.5,
#  16.0,
#  16.9,
#  11.9,
#  19.0,
#  8.6,
#  15.5,
#  13.7,
#  12.2,
#  15.0,
#  11.6,
#  13.8,
#  14.0,
#  11.8,
#  14.9,
#  12.8,
#  16.1,
#  15.0,
#  13.5,
#  13.5,
#  14.4,
#  14.3,
#  14.6,
#  13.8,
#  13.5,
#  13.1,
#  17.0,
#  11.8,
#  13.4,
#  14.0,
#  16.1,
#  14.0,
#  15.0,
#  14.7,
#  14.1,
#  8.8,
#  15.1,
#  13.9,
#  12.3,
#  13.8,
#  13.1,
#  19.1,
#  9.2,
#  17.9,
#  8.1,
#  14.3,
#  15.2,
#  14.1,
#  12.6,
#  20.3,
#  10.7,
#  15.7,
#  20.1,
#  6.7,
#  15.6,
#  11.6,
#  16.4,
#  14.3,
#  11.7,
#  13.3,
#  13.2,
#  14.2,
#  14.1,
#  14.6,
#  15.3,
#  17.4,
#  11.6,
#  15.0,
#  15.1,
#  13.9,
#  11.6,
#  14.6,
#  14.3,
#  11.5,
#  16.7,
#  10.8,
#  15.8,
#  15.0,
#  16.3,
#  15.6,
#  15.8,
#  15.1,
#  21.7,
#  9.0,
#  12.1,
#  15.8,
#  11.7,
#  14.6,
#  15.9,
#  14.1,
#  14.5,
#  21.1,
#  7.1,
#  14.6,
#  15.7,
#  12.1,
#  14.0,
#  13.5,
#  12.0,
#  14.0,
#  13.7,
#  13.1,
#  13.4,
#  15.8,
#  15.0,
#  12.6,
#  15.8,
#  11.1,
#  12.9,
#  15.3,
#  10.1,
#  15.1,
#  13.2,
#  22.8,
#  3.2,
#  0.0,
#  12.8,
#  12.1,
#  18.8,
#  11.2,
#  14.3,
#  14.3,
#  12.6,
#  8.2,
#  16.1,
#  14.2,
#  14.7,
#  7.7,
#  12.5,
#  14.7,
#  19.0,
#  8.0,
#  12.5,
#  12.1,
#  12.6,
#  15.8,
#  12.5,
#  14.2,
#  19.7,
#  14.7,
#  16.6,
#  11.8,
#  14.3,
#  16.2,
#  11.9,
#  12.5,
#  15.5,
#  15.1,
#  15.8,
#  8.9,
#  13.0,
#  13.8,
#  13.0,
#  2.8,
#  14.0,
#  12.8,
#  11.2,
#  21.5,
#  6.8,
#  14.4,
#  14.8,
#  1.2,
#  12.5,
#  12.6,
#  13.8,
#  13.1,
#  6.8,
#  0.0,
#  15.8,
#  12.8,
#  15.7,
#  13.5,
#  12.7,
#  13.8,
#  16.9,
#  12.1,
#  13.6,
#  14.1,
#  13.6,
#  17.0,
#  10.1,
#  13.7,
#  13.0,
#  3.1,
#  5.1,
#  15.2,
#  15.0,
#  19.0,
#  10.2,
#  15.9,
#  15.1,
#  18.5,
#  9.6,
#  11.3,
#  14.9,
#  14.5,
#  14.8,
#  13.3,
#  12.1,
#  12.2,
#  15.0,
#  8.6,
#  13.2,
#  13.5,
#  14.8,
#  13.6,
#  13.5,
#  13.4,
#  19.4,
#  7.7,
#  14.5,
#  12.9,
#  16.1,
#  18.3,
#  10.1,
#  15.2,
#  15.1,
#  7.3,
#  13.6,
#  14.1,
#  16.0,
#  13.3,
#  13.9,
#  15.7,
#  13.3,
#  15.1,
#  14.5,
#  14.1,
#  14.6,
#  13.6,
#  14.1,
#  14.6,
#  13.7,
#  13.0,
#  17.1,
#  10.5,
#  13.5,
#  13.9,
#  22.5,
#  5.2,
#  14.6,
#  15.3,
#  12.3,
#  10.3,
#  11.3,
#  14.9,
#  17.5,
#  9.9,
#  15.0,
#  15.5,
#  13.2,
#  23.0,
#  7.9,
#  16.4,
#  16.0,
#  18.3,
#  8.9,
#  14.8,
#  12.9,
#  12.2,
#  19.5,
#  8.4,
#  14.2,
#  14.1,
#  9.1,
#  10.0,
#  13.1,
#  12.7,
#  14.6,
#  14.2,
#  12.5,
#  12.2,
#  11.8,
#  16.4,
#  11.1,
#  12.9,
#  12.9,
#  15.4,
#  12.7,
#  13.6,
#  12.5,
#  11.5,
#  17.1,
#  11.6,
#  13.0,
#  17.6,
#  11.1,
#  11.8,
#  13.5,
#  13.6,
#  13.4,
#  6.7,
#  12.0,
#  12.1,
#  16.9,
#  9.3,
#  14.3,
#  14.9,
#  14.1,
#  13.3,
#  16.2,
#  12.3,
#  9.3,
#  17.5,
#  13.0,
#  10.5,
#  12.0,
#  13.8,
#  15.5,
#  15.1,
#  13.1,
#  17.4,
#  13.6,
#  8.3,
#  12.5,
#  12.5,
#  12.3,
#  13.9,
#  14.8,
#  15.0,
#  19.9,
#  11.7,
#  10.3,
#  14.0,
#  15.1,
#  15.8,
#  14.2,
#  12.4,
#  11.0,
#  14.0,
#  8.6,
#  12.1,
#  10.2,
#  14.8,
#  13.8,
#  13.5,
#  13.2,
#  13.5,
#  16.2,
#  13.5,
#  14.1,
#  14.1,
#  17.7,
#  12.4,
#  10.2,
#  13.8,
#  14.6,
#  12.1,
#  13.8,
#  12.0,
#  16.9,
#  17.2,
#  10.0,
#  10.0,
#  14.1,
#  10.8,
#  14.2,
#  13.7,
#  15.8,
#  15.2,
#  15.1,
#  9.3,
#  15.7,
#  15.3,
#  15.2,
#  14.8,
#  12.7,
#  15.6,
#  14.2,
#  12.9,
#  ...]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = messages_per_second
  
# Calculating mean and standard deviation
mean = df_network['messages_per_second'].mean()
sd = df_network['messages_per_second'].std()

plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax = sns.lineplot(x = 'time',
            y = 'messages_per_second',
            data = df_network)

# %%
df_network['messages_per_second'].mean()
df_network['messages_per_second'].std()
# Out:
# 3.2455485403072055

# %%
df_iota_small_grouped = df_iota_small.groupby("packet_size_bytes").mean()

# %%
df_iota_small_grouped
# Out:
#                        datetime  same_auth_sub  local_pow  timeToSync  \
# packet_size_bytes
# 2                  1.648770e+12       0.888889        0.0  447.511111
# 4                  1.648789e+12       0.895349        0.0  382.674419
# 8                  1.649105e+12       1.000000        0.0  208.400000
# 16                 1.649234e+12       1.000000        0.0  218.300000
# 32                 1.649234e+12       1.000000        0.0  220.972222
#
#                    timeToReceiveMessage
# packet_size_bytes
# 2                           3333.355556
# 4                           3977.383721
# 8                           2946.640000
# 16                          3162.250000
# 32                          3489.861111
